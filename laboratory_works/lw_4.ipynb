# %% [markdown]
# # Laboratorul nr. 4

# %% [markdown]
# ## POO

# %% [markdown]
# Trebuie să dezvoltați clasa `Pet`, care va reprezenta animalul de companie în contextul sistemului de gestionare a hotelului pentru animale. Clasa trebuie să încapsuleze următoarele proprietăți:
#
# 1. **name**: numele animalului de companie.
# 2. **breed**: rasa animalului de companie.
# 3. **age**: vârsta animalului de companie.
#
# Pentru fiecare dintre aceste proprietăți este necesar să se implementeze metode de acces (gettere) și metode de modificare (settere). Pentru aceasta, utilizați decoratorii `@property` și `@<property_name>.setter`.
#
# #### Cerințe:
# 1. Creați clasa `Pet`, care acceptă trei parametri în constructor: `name`, `breed` și `age`.
# 2. Implementați gettere pentru fiecare dintre aceste proprietăți folosind decoratorul `@property`.
# 3. Implementați settere pentru fiecare dintre aceste proprietăți folosind decoratorul `@<property_name>.setter`.
# 4. Demonstrați funcționarea clasei creând un obiect `Pet` cu valori definite și modificând proprietățile acestuia prin settere.

# %%
class Pet:
    def __init__(self, name, breed, age):
        # Scrie soluția aici
        pass

# Exemplu:
pet = Pet("Lara", "Cat", 3)
print(pet.name)  # Lara
pet.age = 4
print(pet.age)  # 4

# %% [markdown]
# Creați două clase moștenitoare Cat și Dog, care vor adăuga atribute și metode unice pentru fiecare tip de animal.

# %% [markdown]
# #### Cerințe:
#
# 1. **Clasa `Cat`**, care moștenește de la `Pet`, trebuie să adauge:
#    - **favorite_toy** (jucăria preferată).
#    - Metoda `play()`, care returnează un șir de caractere care descrie jocul animalului de companie cu jucăria preferată.
#
# 2. **Clasa `Dog`**, care moștenește și ea de la `Pet`, trebuie să adauge:
#    - **trick** (truc pe care animalul de companie îl poate executa).
#    - Metoda `perform_trick()`, care returnează un șir cu descrierea executării trucului.
#
# 3. Utilizați **setterele** pentru a modifica valorile, de exemplu, pentru a seta jucăria preferată a pisicii și pentru a executa trucul câinelui.

# %%
class Cat(Pet):
    def __init__(self, name, breed, age, favorite_toy):
        # Scrie soluția aici
        pass

class Dog(Pet):
    def __init__(self, name, breed, age, trick):
        # Scrie soluția aici
        pass

# Exemplu:
cat = Cat("Lara", "Cat", 3, "ball")
dog = Dog("Rex", "Dog", 5, "wags its tail")

print(cat.name)  # Lara
cat.favorite_toy = "string"
print(cat.play())  # Lara plays with string
print(dog.name)  # Rex
print(dog.perform_trick())  # Рекс выполняет трюк: wags its tail

# %% [markdown]
# Adăugați în clasele Cat și Dog metoda `make_sound()`, care va emite un sunet caracteristic pentru fiecare animal.
# În metoda `make_sound()`, utilizați polimorfismul cu `@property`, astfel încât fiecare clasă să implementeze propriul sunet.

# %% [markdown]
# #### Cerințe:
#
# 1. **Clasa de bază `Pet`**:
#    - Trebuie să conțină atributele: `name` (numele animalului de companie), `breed` (rasa) și `age` (vârsta).
#    - Pentru fiecare animal de companie trebuie să existe o metodă `sound()`, care va fi redefinită în clasele descendente.
#    - Metoda `sound()` trebuie să fie abstractă (utilizând excepția `NotImplementedError`), ceea ce înseamnă că clasele descendente trebuie să implementeze această metodă.
#
# 2. **Clasa `Cat`, moștenită de la `Pet`**:
#    - Adăugați atributul `favorite_toy` (jucăria preferată).
#    - Redefiniti metoda `sound()` pentru a emite un sunet tipic pentru pisici, de exemplu, `„Meow!”`.
#    - Adăugați metoda `make_sound()`, care va emite șirul: `„Numele animalului de companie spune: Meow!”` folosind polimorfismul prin `@property`.
#
# 3. **Clasa `Dog`, moștenită de la `Pet`**:
#    - Adăugați atributul `trick` (truc pe care animalul de companie îl poate executa).
#    - Redefiniti metoda `sound()` pentru a emite un sunet tipic pentru câini, de exemplu, `„Woof!”`.
#    - Adăugați metoda `make_sound()`, care va afișa șirul: `„Numele animalului de companie spune: Woof!”` folosind polimorfismul prin `@property`.
#
# 4. **Utilizarea polimorfismului**:
#    - În metoda `make_sound()`, aplicați polimorfismul utilizând `@property` pentru fiecare clasă, astfel încât metoda să determine dinamic ce sunet reproduce animalul de companie în funcție de tipul său.

# %%
class Pet:
    def __init__(self, name, breed, age):
        self._name = name
        self._breed = breed
        self._age = age

    def sound(self):
        raise NotImplementedError("The sound method must be redefined in the child class.")

class Cat(Pet):
    def __init__(self, name, breed, age, favorite_toy):
        pass
    def sound(self):
        # Scrie soluția aici
        pass

class Dog(Pet):
    def __init__(self, name, breed, age, trick):
        pass
    def sound(self):
        # Scrie soluția aici
        pass

# Exemplu:
cat = Cat("Lara", "Cat", 3)
dog = Dog("Rex", "Dog", 5)

print(cat.sound)  # Lara says: Meow!
print(dog.sound)  # Rex says: Woof!
