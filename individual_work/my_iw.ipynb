# %% [markdown]
# ### Lucrare individuală
#
# #### Tema: Dezvoltarea unei biblioteci matematice folosind OOP
#
# ##### **Scop:**
#
# Dezvoltarea unei biblioteci matematice pentru lucrul cu vectori, matrice și ecuații, destinată optimizării și simplificării calculelor.
#
# ---
#
# ### **Sarcina**
#
# Trebuie să dezvoltați un proiect care să includă:
#
# #### **1. Implementarea claselor**
#
# 1. **Clasa `Vector`**
#
#    * Câmpuri: coordonatele vectorului (stocate ca listă).
#    * Metode:
#
#      * Lungimea vectorului.
#      * Produs scalar al două vectori.
#      * Unghiul dintre doi vectori.
#      * Adunarea și scăderea vectorilor.
#      * Înmulțirea vectorului cu un scalar.
#      * Verificarea coliniarității vectorilor.
#
# 2. **Clasa `Matrix`**
#
#    * Câmpuri: listă bidimensională pentru stocarea elementelor matricei.
#    * Metode:
#
#      * Adunarea și scăderea matricelor.
#      * Înmulțirea matricei cu un vector.
#      * Înmulțirea matricelor.
#      * Transpunerea matricei.
#      * Determinantul matricei (pentru matrice pătrată).
#      * Rezolvarea unui sistem de ecuații liniare prin metoda Gauss (dacă matricea este pătrată).
#
# 3. **Clasa `EquationSolver`**
#
#    * Câmpuri: coeficienții și parametrii ecuației.
#    * Metode:
#
#      * Rezolvarea ecuației liniare de forma `ax + b = 0`.
#      * Rezolvarea ecuației pătratice de forma `ax² + bx + c = 0`.
#      * Rezolvarea sistemului de ecuații (folosind metodele din clasa `Matrix`).
#      * Afișarea soluțiilor într-un format ușor de citit.
#
# P.S. Puteți adăuga încă 1–2 clase cu implementări suplimentare, de exemplu, calculul valorii minime/maximale a unei funcții sau găsirea punctului de intersecție al funcțiilor (rămâne la discreția dvs.).
#
# ---
#
# #### **2. Interacțiunea cu utilizatorul**
#
# Creați o interfață pentru interacțiunea cu programul:
#
# * Utilizatorul alege cu ce obiect matematic vrea să lucreze (vector, matrice sau ecuație).
# * Programul solicită datele de intrare (de exemplu, coordonatele vectorului, elementele matricei sau coeficienții ecuației).
# * Se efectuează operațiile indicate și se afișează rezultatul.
#
# ---
#
# #### **3. Cerințe suplimentare**
#
# * Adăugați gestionarea erorilor:
#
#   * Date de intrare incorecte.
#   * Nepotrivirea dimensiunilor matricelor sau vectorilor.
#
# ---
#
# #### **Exemplu de funcționare a programului:**
#
# 1. **Alegerea acțiunii:**
#
#    ```
#    1. Lucru cu vectori
#    2. Lucru cu matrici
#    3. Rezolvarea ecuațiilor
#    Alegeți acțiunea: 1
#    ```
#
# 2. **Exemplu de lucru cu vectori:**
#
#    ```
#    Introduceți coordonatele primului vector (separate prin spațiu): 3 4
#    Introduceți coordonatele celui de-al doilea vector (separate prin spațiu): 1 2
#    Alegeți operația:
#    1. Lungimea vectorului
#    2. Produs scalar
#    3. Unghiul dintre vectori
#    4. Adunarea vectorilor
#    5. Înmulțirea cu un scalar
#    ```
#
# 3. **Exemplu de lucru cu matrici:**
#
#    ```
#    Introduceți dimensiunea matricei (linii și coloane): 2 2
#    Introduceți elementele primei matrici (pe rânduri):
#    1 2
#    3 4
#    Introduceți elementele celei de-a doua matrici:
#    5 6
#    7 8
#    Alegeți operația:
#    1. Adunare
#    2. Înmulțire
#    3. Transpunere
#    ```
#
# 4. **Exemplu de lucru cu ecuații:**
#
#    ```
#    Alegeți tipul ecuației:
#    1. Liniară (ax + b = 0)
#    2. Pătratică (ax² + bx + c = 0)
#    Introduceți coeficienții: 1 -3 2
#    Rezolvare: x₁ = 1, x₂ = 2
#    ```
#
# ---
#
# #### **Criterii de evaluare:**
#
# 1. Completitudinea implementării claselor și metodelor.
# 2. Prezența gestionării erorilor.
# 3. Ușurința interfeței.
# 4. Calitatea codului, documentației și comentariilor.

# %%
# Напиши решение тут
