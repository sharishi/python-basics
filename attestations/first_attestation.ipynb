# %% [markdown]
# # Atestarea nr. 1

# %% [markdown]
# ### Sarcina nr. 1
# Scrieți un program care acceptă dicționarul `input_dict` și returnează un șir de caractere de forma: `cheie=valoare&cheie=valoare`
#
# Șirul trebuie să fie sortat lexicografic după cheile dicționarului inițial. Salvați răspunsul obținut în `result`.

# %%
input_dict = {'lesson': 2, 'task': 4, 'course': 'python'}
result = 'course=python&lesson=2&task=4'

# %%
# Scrie soluția aici

# %% [markdown]
# ### Sarcina nr. 2
# Scrieți un program care să primească un număr n și să verifice dacă fiecare cifră a acestuia este multiplu al cifrei aflate în stânga ei. Salvați răspunsul în `result` sub forma unui tablou de valori booleene ale rezultatelor verificărilor.
#
# `result` trebuie să înceapă întotdeauna cu False, deoarece în stânga primei cifre nu există nimic.
#
# Exemplu:
# ```python
# n = 462825624
# result = [False, False, False, True, False, False, False, False, True]
# ```

# %%
# Scrie soluția aici

# %% [markdown]
# ### Sarcina nr. 3
# Scrieți un program care analizează textul introdus și returnează statistici. Este necesar să implementați **mai multe funcții**, fiecare dintre ele îndeplinind o anumită sarcină.
#
# ---
#
# **Să ne oprim mai detaliat:**
# 1. Scrieți funcția **`count_letters(text)`**, care returnează numărul de litere (numai latine și chirilice) din text.
# 2. Scrieți funcția **`count_digits(text)`**, care returnează numărul de cifre.
# 3. Scrieți funcția **`count_words(text)`**, care returnează numărul de cuvinte. Un cuvânt este o secvență de litere.
# 4. Scrieți funcția **`analyze_text(text)`**, care apelează toate funcțiile de mai sus și returnează rezultatul general sub forma unui dicționar:
#    ```python
#    {
#        „letters”: <numărul de litere>,
#        „digits”: <numărul de cifre>,
#        „words”: <numărul de cuvinte>
#    }
#    ```
# 5. Afișați rezultatul funcției **`analyze_text`** pentru șirul introdus.
#
#
# **Exemplu de funcționare a programului:**
#
# Intrare:
# ```
# Introduceți textul: Bună, acesta este textul de test 123, cu 7 cuvinte!
# ```
#
# Ieșire:
# ```
# Analiza textului:
# Număr de litere: 30
# Număr de cifre: 4
# Număr de cuvinte: 6
# ```

# %%
# Scrie soluția aici

# %% [markdown]
# ### Sarcina: Distribuirea elevilor pe facultățile Hogwarts
#
# La Hogwarts are loc ceremonia de distribuire a bobocilor. Pe baza calităților pe care le vede pălăria de distribuire, elevii sunt înscriși la una dintre facultăți:
#
# - **Gryffindor**: curaj, bunătate, hotărâre.
# - **Hufflepuff**: sârguință, prietenie, toleranță.
# - **Slytherin**: cunoaștere, inventivitate, judecată.
# - **Slytherin**: ambiție, ingeniozitate, determinare.
#
# Este necesar să se implementeze funcția `sorting_hat()`, care acceptă un dicționar cu elevii, unde:
# - **Cheia** — numele elevului.
# - **Valoarea** — calitatea care determină facultatea din care face parte.
#
# Funcția trebuie să returneze două rezultate:
#
# 1. **sorted_students** — dicționarul în care cheia este numele elevului, iar valoarea este facultatea la care este înscris.
#    - Datele trebuie sortate după numele facultății, apoi după numele elevului.
#
# 2. **departments** — dicționar în care cheia este facultatea, iar valoarea este numărul de elevi înscriși.
#    - Datele trebuie sortate după numele facultății.
#
# ### Exemplu de date de intrare:
# ```python
# new_students = {
#     'Sirius Black': "curaj",
#     "Amanda Korschun": "cunoaștere",
#     "Penelope Woolpingold": "inginerie",
#     "Arthur Potter": "curaj",
#     "Tesaya Black": "inventivitate"
# }
# ```
#
#
# ### Exemplu de rezultat:
# ```python
# # sorted_students:
# {
#     "Arthur Potter": "Gryffindor",
#     "Sirius Black": "Gryffindor",
#     "Amanda Korschun": "Ravenclaw",
#     "Tesaya Black": "Ravenclaw",
#     'Penelope Vulpingold': "Slytherin"
# }
#
# # departments:
# {
#     "Gryffindor": 2,
#     "Ravenclaw": 2,
#     "Hufflepuff": 0,
#     "Slytherin": 1
# }
# ```

# %%
# Scrie soluția aici

# %% [markdown]
# ### Sarcina nr. 5
# În `my_string`  este stocată o șir de caractere criptată, de exemplu:
# ```python
# # Șir de caractere criptat
# my_string = 'sccfxpzijc is fuc bcd sxcizicg'
# ```
# În dicționarul `secret_dict`  este stocată cheia de criptare, un set de caractere care trebuie înlocuite:
#
# ```python
# # Dicționar de criptare
#
#
# secret_dict = {
# 'v': 'w',
# 'x': 'y',
# 'i': 'h',
# 'q': 'l',
# 'c': 'n',
# 'o': 'm',
# 'b': 'a',
# 'f': 'r',
# 'j': 'o',
# 's': 'e',
# 'z': 't',
# 'g': 'k',
# 'l': ' ',
# 'k': 'c',
# 'm': 'p',
# 'n': 'i',
# 'w': 's',
# 'd': 'f',
# 'u': 'u',
# 'r': 'd',
# 'e': 'x',
# 'y': 'g'}
# ```
# Astfel, dicționarul `secret_dict` ne spune că în șirul `my_string` litera `v` trebuie înlocuită cu `m`, `s` cu «e» și așa mai departe. Dacă facem aceste înlocuiri în șirul my_string, atunci `sckfxmznjclnwlduclbcrlseknzncy` se va transforma în `encryption is fun and exciting`.
#
# Scrieți un program care descifrează șirul `my_string = «nlbolyjccblyszlblzsclnclmxzijc»` folosind dicționarul secret_dict. Salvați șirul descifrat în variabila decrypted_string.

# %%
# Scrie soluția aici
